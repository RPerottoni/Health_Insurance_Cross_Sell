# %% [markdown]
# # PA004 - HEALTH INSURANCE CROSS-SELL

# %% [markdown]
# ## 1.0 - API Tester

# %%
import requests
import pandas as pd

# %%
# Load Datasets
df_test = pd.read_csv('C:/Users/perot/Documents/ds_repos/projects/Health_Insurance_Cross_Sell/data/raw/test.csv')

# %%
df_test = df_test.sample(1000)

# %%
df_test
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 75421   456531  Female   22                1           29                   1
# 46106   427216  Female   23                1           29                   1
# 88350   469460    Male   52                1            8                   1
# 92800   473910  Female   24                1           35                   1
# 76998   458108    Male   24                1           49                   0
# ...        ...     ...  ...              ...          ...                 ...
# 89088   470198    Male   23                1            8                   0
# 115018  496128  Female   22                1           47                   0
# 44479   425589  Female   21                1           11                   0
# 115952  497062  Female   73                1           28                   1
# 62330   443440  Female   64                1           28                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 75421     < 1 Year             No           31507                   152
# 46106     < 1 Year            Yes           81791                   152
# 88350     1-2 Year             No           34208                   124
# 92800     < 1 Year             No           23867                   152
# 76998     < 1 Year            Yes           27665                   152
# ...            ...            ...             ...                   ...
# 89088     < 1 Year            Yes           44102                    26
# 115018    < 1 Year            Yes           23518                   152
# 44479     1-2 Year            Yes           21989                    26
# 115952   > 2 Years            Yes           33573                    26
# 62330     1-2 Year            Yes           32401                   124
#
#         Vintage
# 75421       295
# 46106       206
# 88350       116
# 92800       201
# 76998        61
# ...         ...
# 89088       270
# 115018      220
# 44479       254
# 115952       16
# 62330       216
#
# [1000 rows x 11 columns]

# %%
# convert dataframe to json
data = json.dumps( df_test.to_dict( orient='records' ) )

# %%
data
# Out:
# '[{"id": 456531, "Gender": "Female", "Age": 22, "Driving_License": 1, "Region_Code": 29, "Previously_Insured": 1, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "No", "Annual_Premium": 31507, "Policy_Sales_Channel": 152, "Vintage": 295}, {"id": 427216, "Gender": "Female", "Age": 23, "Driving_License": 1, "Region_Code": 29, "Previously_Insured": 1, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 81791, "Policy_Sales_Channel": 152, "Vintage": 206}, {"id": 469460, "Gender": "Male", "Age": 52, "Driving_License": 1, "Region_Code": 8, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 34208, "Policy_Sales_Channel": 124, "Vintage": 116}, {"id": 473910, "Gender": "Female", "Age": 24, "Driving_License": 1, "Region_Code": 35, "Previously_Insured": 1, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "No", "Annual_Premium": 23867, "Policy_Sales_Channel": 152, "Vintage": 201}, {"id": 458108, "Gender": "Male", "Age": 24, "Driving_License": 1, "Region_Code": 49, "Previously_Insured": 0, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 27665, "Policy_Sales_Channel": 152, "Vintage": 61}, {"id": 425297, "Gender": "Female", "Age": 22, "Driving_License": 1, "Region_Code": 45, "Previously_Insured": 1, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "No", "Annual_Premium": 46864, "Policy_Sales_Channel": 152, "Vintage": 66}, {"id": 482850, "Gender": "Female", "Age": 41, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 43173, "Policy_Sales_Channel": 13, "Vintage": 224}, {"id": 502783, "Gender": "Female", "Age": 26, "Driving_License": 1, "Region_Code": 3, "Previously_Insured": 0, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 24633, "Policy_Sales_Channel": 152, "Vintage": 175}, {"id": 416896, "Gender": "Female", "Age": 28, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 1, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "No", "Annual_Premium": 47877, "Policy_Sales_Channel": 152, "Vintage": 116}, {"id": 458264, "Gender": "Male", "Age": 25, "Driving_License": 1, "Region_Code": 10, "Previously_Insured": 0, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 21404, "Policy_Sales_Channel": 152, "Vintage": 145}, {"id": 448713, "Gender": "Male", "Age": 24, "Driving_License": 1, "Region_Code": 45, "Previously_Insured": 0, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 30407, "Policy_Sales_Channel": 163, "Vintage": 90}, {"id": 490713, "Gender": "Male", "Age": 47, "Driving_License": 1, "Region_Code": 46, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 45267, "Policy_Sales_Channel": 124, "Vintage": 75}, {"id": 507257, "Gender": "Male", "Age": 26, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 1, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "No", "Annual_Premium": 59659, "Policy_Sales_Channel": 152, "Vintage": 161}, {"id": 486372, "Gender": "Female", "Age": 25, "Driving_License": 1, "Region_Code": 18, "Previously_Insured": 1, "Vehicle_Age": "< 1 Year", "Vehicle_Damage": "No", "Annual_Premium": 26201, "Policy_Sales_Channel": 152, "Vintage": 147}, {"id": 491840, "Gender": "Female", "Age": 40, "Driving_License": 1, "Region_Code": 11, "Previously_Insured": 1, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "No", "Annual_Premium": 34633, "Policy_Sales_Channel": 124, "Vintage": 199}, {"id": 450436, "Gender": "Male", "Age": 75, "Driving_License": 1, "Region_Code": 28, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 62767, "Policy_Sales_Channel": 124, "Vintage": 205}, {"id": 457444, "Gender": "Male", "Age": 41, "Driving_License": 1, "Region_Code": 6, "Previously_Insured": 0, "Vehicle_Age": "1-2 Year", "Vehicle_Damage": "Yes", "Annual_Premium": 29490, "Policy_Sales_Channel": 124, "Vintage": 249}, {"id": 441346, "Gender": "Female",  ...

# %%
# API Call
url = 'https://healthinsurance-api.onrender.com/healthinsurance/predict'
#url = 'http://127.0.0.1:5000/healthinsurance/predict'
header = {'Content-type': 'application/json' }

r = requests.post( url, data=data, headers=header )
print( 'Status Code {}'.format( r.status_code ) )

# %%
d2 = pd.DataFrame( r.json(), columns=r.json()[0].keys() )

# %%
D2

# %% [markdown]
# # Analysis after Prediction

# %%
# Get Data
df = pd.read_csv('C:/Users/perot/Documents/ds_repos/projects/Health_Insurance_Cross_Sell/data/processed/datascore.csv')

# %%
df.head()
